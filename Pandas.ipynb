# %% [markdown]
# ##### pandas
#
# > pandas is a powerfull python library for manipulation and analysis of data
#
# > its a open source library
#
# > fast(built on top of numpy),flexible(different resource),prouctive library

# %% [markdown]
# #### install

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# #### series - one dimensional array (data structure)with label

# %%
l1 = [1,2,3,4,5]
type(l1)
# Out:
# list

# %%
s=pd.Series(l1,index =["a","b","c","d","e"],name="my series")

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %%
s['a']
# Out:
# np.int64(1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s.index[0]
# Out:
# 'a'

# %% [markdown]
# ### Note: index in series are immutable(can't change)

# %%
s.index[0]='z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 s.index[0]='z'
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# changing the index of pandas series

s.rename(index={'b':'y'},inplace=True)

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: my series, dtype: int64

# %% [markdown]
# ### dataframe - its a 2 d array(just like tables)

# %%
import numpy as np

# %%
dict1= {'Name':['Virat','Rohit','dhoni','jadeja','bumrah','virat'],
        'age':[34,33,40,32,30,35],
        'marks':[85,90,75,80,70,np.nan],
        'role':['batsman','batsman','wicket keeper','all rounder','bowler','bowler']
        }
pd.DataFrame(dict1)
# Out:
#      Name  age  marks           role
# 0   Virat   34   85.0        batsman
# 1   Rohit   33   90.0        batsman
# 2   dhoni   40   75.0  wicket keeper
# 3  jadeja   32   80.0    all rounder
# 4  bumrah   30   70.0         bowler
# 5   virat   35    NaN         bowler

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#      Name  age  marks           role
# 0   Virat   34   85.0        batsman
# 1   Rohit   33   90.0        batsman
# 2   dhoni   40   75.0  wicket keeper
# 3  jadeja   32   80.0    all rounder
# 4  bumrah   30   70.0         bowler
# 5   virat   35    NaN         bowler

# %%
df.head
# Out:
# <bound method NDFrame.head of      Name  age  marks           role
# 0   Virat   34   85.0        batsman
# 1   Rohit   33   90.0        batsman
# 2   dhoni   40   75.0  wicket keeper
# 3  jadeja   32   80.0    all rounder
# 4  bumrah   30   70.0         bowler
# 5   virat   35    NaN         bowler>

# %%
df.tail(2)
# Out:
#      Name  age  marks    role
# 4  bumrah   30   70.0  bowler
# 5   virat   35    NaN  bowler

# %%
len(df)
# Out:
# 6

# %%
df.count()
# Out:
# Name     6
# age      6
# marks    5
# role     6
# dtype: int64

# %%
df.columns
# Out:
# Index(['Name', 'age', 'marks', 'role'], dtype='object')

# %%
df['Name']
# Out:
# 0     Virat
# 1     Rohit
# 2     dhoni
# 3    jadeja
# 4    bumrah
# 5     virat
# Name: Name, dtype: object

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name'].value_counts()
# Out:
# Name
# Virat     1
# Rohit     1
# dhoni     1
# jadeja    1
# bumrah    1
# virat     1
# Name: count, dtype: int64
